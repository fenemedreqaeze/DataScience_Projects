# %% [markdown]
# # Speed Dating - Part II

# %% [markdown]
# Let's try to produce our first visualisations with Seaborn. Based on the exploration you realized, try to find good representations of the dataset that allow to summarize some statistics as well as relationships between variables.

# %% [markdown]
# ## Import library
#
# First step in a machine learning work is to import the adequate library.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read CSV
# After importing the adequate library,

# %%
pd.set_option('display.max_columns', 1000)
df = pd.read_csv("Speed.csv", encoding= 'unicode_escape')
df1 = df.copy()
print(df1)
# Out:
#       iid    id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0       1   1.0       0    1       1     1     10         7       NaN      4
# 1       1   1.0       0    1       1     1     10         7       NaN      3
# 2       1   1.0       0    1       1     1     10         7       NaN     10
# 3       1   1.0       0    1       1     1     10         7       NaN      5
# 4       1   1.0       0    1       1     1     10         7       NaN      7
# ...   ...   ...     ...  ...     ...   ...    ...       ...       ...    ...
# 8373  552  22.0       1   44       2    21     22        14      10.0      5
# 8374  552  22.0       1   44       2    21     22        13      10.0      4
# 8375  552  22.0       1   44       2    21     22        19      10.0     10
# 8376  552  22.0       1   44       2    21     22         3      10.0     16
# 8377  552   NaN       1   44       2    21     22         2      10.0     15
#
# ...

# %% [markdown]
# ## Representations

# %% [markdown]
# ## Summarize some statistics

# %% [markdown]
# ## Relationships between variables
